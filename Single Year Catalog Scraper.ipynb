# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = "https://courses.rice.edu/admweb/!SWKSCAT.cat?p_acyr_code=2023&p_action=CATASRCH&p_onebar=&p_mode=AND&p_subj_cd=&p_subj=&p_dept=&p_school=&p_df=%2B&p_submit="

# %%
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
table = soup.find("table", class_="table-condensed")

# %%
courses = table.find_all("tr")

# %%
skip = True
data = []
for course in courses:
    if skip:
        skip = False
        continue
    course_code = course.find("td", class_="cataCourse")
    course_code_link = course_code.find("a")["href"]
    course_code = course_code.text
    title = course.find("td", class_="cataTitle").text
    for idx, item in enumerate(course.find_all("td", class_="cataDist")):
        if idx == 0:
            dist_group = item.text
        else:
            analyzing_div = item.text
    credits = course.find("td", class_="credits").text
    data.append([
        course_code,
        course_code_link,
        title,
        dist_group,
        analyzing_div,
        credits
    ])
df = pd.DataFrame(data, columns=['Course', 'URL', 'Title', 'Distribution Group', 'Analyzing Diversity', 'Credits'])

# %%
df
# Out:
#         Course                                                URL  \
# 0     AAAS 200  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
# 1     AAAS 300  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
# 2     AAAS 510  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
# 3     AAAS 600  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
# 4     AFSC 101  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
# ...        ...                                                ...
# 5990  UNIV 502  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
# 5991  UNIV 555  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
# 5992  UNIV 594  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
# 5993  UNIV 599  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
# 5994  UNIV 677  /courses/!SWKSCAT.cat?p_action=CATALIST&p_acyr...
#
#                                Title    Distribution Group  \
# 0                      INTRO TO AAAS  Distribution Group I
# 1                WRITING BLACK LIVES  Distribution Group I
# 2         INTRO TO DIASPORIC STUDIES
# 3       AF & AFAM STUDIES COLLOQUIUM
# 4           FOUNDATION OF THE USAF I
# ...                              ...                   ...
# 5990   PRACTICUM IN COLLEGE TEACHING
# 5991    INTER-INSTITUTIONAL TRANSFER
# 5992  RESPONSIBLE CONDUCT - RESEARCH
# 5993              TEACHING PORTFOLIO
# 5994                  SPECIAL TOPICS
#
#      Analyzing Diversity Credits
# 0                              3
# 1                              3
# 2                              3
# 3                              0
# 4                              2
# ...                  ...     ...
# 5990                           3
# 5991                      1 TO 6
# 5992                           1
# 5993                           2
# 5994                      1 TO 4
#
# [5995 rows x 6 columns]
